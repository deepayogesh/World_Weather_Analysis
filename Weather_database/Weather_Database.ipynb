# %%
# !jupyter nbextension enable --py gmaps
# !jupyter nbextension enable --py widgetsnbextension
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# use citypy mdule to import city data 
from citipy import citipy

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
#-------------------------------------------------------------------------
set_count = 1
# create a city list to hold the city names 
cities =[]
# to identify the nearest city will pass the lattitude and longitude to the citypy module and get city name 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)     
#  --------------------------------------------------------------------------------------
for i in range(len(cities)):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]   
#------------------------------------------------------
city_data = []   # data list to hold the data 
print("Beginning Data  ")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list. -700 
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]  # This [0] important as weather is dict in jason form
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_desc})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data  Complete      ")
# Out:
# Beginning Data
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | narsaq
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | santa cruz
# Processing Record 6 of Set 1 | mandurah
# Processing Record 7 of Set 1 | lorengau
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | ossora
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | tucurui
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | mount isa
# Processing Record 18 of Set 1 | arlit
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | kapaa
# ...

# %%
city_data_df =pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Jamestown  42.0970  -79.2353     78.12        81          90        5.99
# 1      Rikitea -23.1203 -134.9692     69.21        54           0        0.89
# 2       Narsaq  60.9167  -46.0500     50.22        84          89        4.76
# 3     Bengkulu  -3.8004  102.2655     75.06        88           9        4.21
# 4   Santa Cruz -17.8000  -63.1667     89.65        35          20       26.46
# 5     Mandurah -32.5500  115.7000     55.22        69         100       16.53
# 6     Lorengau  -2.0226  147.2712     80.60        76          67        6.67
# 7        Bluff -46.6000  168.3333     42.80        72         100       11.79
# 8       Ossora  59.2353  163.0719     58.15        87          99        5.39
# 9  Tuktoyaktuk  69.4541 -133.0374     60.80        51          40       16.11
#
#   Country Weather Description
# 0      US          light rain
# 1      PF           clear sky
# ...

# %%
city_data_df.index_label="City_ID"

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index =False)    #  index_label="City_ID")
